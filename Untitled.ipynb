# %%
# %run deploy.py
# Out:
# 2025-10-25 07:22:19.480 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-25 07:22:19.625
# ...
#   command:
#
#     streamlit run deploy.py [ARGUMENTS]
# 2025-10-25 07:22:19.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-25 07:22:19.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-25 07:22:19.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-25 07:22:19.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-25 07:22:19.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
